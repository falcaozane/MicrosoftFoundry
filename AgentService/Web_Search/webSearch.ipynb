# %% [markdown]
# ## Web Search with Foundry Agent

# %% [markdown]
# ![lab_flow](./Assets/lab_flow.png)

# %% [markdown]
# ### Installing Required Libraries

# %%
# %pip install azure-ai-projects==2.0.0b2 openai==1.109.1 python-dotenv azure-identity
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: azure-ai-projects==2.0.0b2 in c:\users\zvijayfa\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (2.0.0b2)
# Requirement already satisfied: openai==1.109.1 in c:\users\zvijayfa\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (1.109.1)
# Requirement already satisfied: python-dotenv in c:\users\zvijayfa\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (1.2.2)
# Requirement already satisfied: azure-identity in c:\users\zvijayfa\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (1.25.3)
# Requirement already satisfied: isodate>=0.6.1 in c:\users\zvijayfa\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from azure-ai-projects==2.0.0b2) (0.7.2)
# Requirement already satisfied: azure-core>=1.35.0 in c:\users\zvijayfa\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from azure-ai-projects==2.0.0b2) (1.39.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\zvijayfa\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from azure-ai-projects==2.0.0b2) (4.15.0)
# Requirement already satisfied: azure-storage-blob>=12.15.0 in c:\users\zvijayfa\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from azure-ai-projects==2.0.0b2) (12.28.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\zvijayfa\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from openai==1.109.1) (4.10.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\zvijayfa\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from openai==1.109.1) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\zvijayfa\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from openai==1.109.1) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\zvijayfa\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from openai==1.109.1) (0.14.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\zvijayfa\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from openai==1.109.1) (2.13.1)
# Requirement already satisfied: sniffio in c:\users\zvijayfa\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from openai==1.109.1) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\zvijayfa\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from openai==1.109.1) (4.67.1)
# Requirement already satisfied: cryptography>=2.5 in c:\users\zvijayfa\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from azure-identity) (46.0.7)
# Requirement already satisfied: msal>=1.35.1 in c:\users\zvijayfa\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from azure-identity) (1.36.0)
# Requirement already satisfied: msal-extensions>=1.2.0 in c:\users\zvijayfa\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from azure-identity) (1.3.1)
# Requirement already satisfied: idna>=2.8 in c:\users\zvijayfa\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from anyio<5,>=3.5.0->openai==1.109.1) (3.10)
# Requirement already satisfied: requests>=2.21.0 in c:\users\zvijayfa\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from azure-core>=1.35.0->azure-ai-projects==2.0.0b2) (2.32.5)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\zvijayfa\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from cryptography>=2.5->azure-identity) (2.0.0)
# Requirement already satisfied: certifi in c:\users\zvijayfa\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from httpx<1,>=0.23.0->openai==1.109.1) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in c:\users\zvijayfa\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from httpx<1,>=0.23.0->openai==1.109.1) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\zvijayfa\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai==1.109.1) (0.16.0)
# Requirement already satisfied: PyJWT<3,>=1.0.0 in c:\users\zvijayfa\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from PyJWT[crypto]<3,>=1.0.0->msal>=1.35.1->azure-identity) (2.12.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\zvijayfa\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pydantic<3,>=1.9.0->openai==1.109.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.1 in c:\users\zvijayfa\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pydantic<3,>=1.9.0->openai==1.109.1) (2.46.1)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\zvijayfa\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pydantic<3,>=1.9.0->openai==1.109.1) (0.4.2)
# Requirement already satisfied: colorama in c:\users\zvijayfa\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from tqdm>4->openai==1.109.1) (0.4.6)
# Requirement already satisfied: pycparser in c:\users\zvijayfa\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from cffi>=2.0.0->cryptography>=2.5->azure-identity) (2.23)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\zvijayfa\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests>=2.21.0->azure-core>=1.35.0->azure-ai-projects==2.0.0b2) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\zvijayfa\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests>=2.21.0->azure-core>=1.35.0->azure-ai-projects==2.0.0b2) (2.5.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: C:\Users\zvijayfa\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %% [markdown]
# ### Setting Up the Environment Variables

# %%
import os
from dotenv import load_dotenv
from azure.identity import DefaultAzureCredential
from azure.ai.projects import AIProjectClient
from azure.ai.projects.models import PromptAgentDefinition, WebSearchPreviewTool, ApproximateLocation

load_dotenv()

foundry_project_endpoint = os.getenv("FOUNDRY_PROJECT_ENDPOINT")
model_deployment_name = os.getenv("MODEL_DEPLOYMENT_NAME")

# %% [markdown]
# ### Setting Up the Foundry Project Client

# %%
project_client = AIProjectClient(
    endpoint=foundry_project_endpoint,
    credential=DefaultAzureCredential(),
)

# %% [markdown]
# ### Creating the OpenAI Client

# %%
openai_client = project_client.get_openai_client()

# %% [markdown]
# ### Create an Agent with the Web Search Tool

# %%
agent = project_client.agents.create_version(
    agent_name="web-search-agent",
    definition=PromptAgentDefinition(
        model = model_deployment_name,
        instructions="You are a helpful assistant that uses web search to answer user queries.",
        tools = [
            WebSearchPreviewTool()
        ]
    )
)

# %% [markdown]
# ### Creating a Conversation Object for the Agent Chat System

# %%
# create a conversation to use with the agent
conversation = openai_client.conversations.create()
print(f"Created conversation with id: {conversation.id}")
# Out:
# Created conversation with id: conv_e7f95405f842e23700hr0erpQbT5WFwgwZBrVWLgB1KTgW2ok4

# %% [markdown]
# ### Chat With the Agent

# %%
user_query = "What are the latest advancements in renewable energy?"

# %%
response = openai_client.responses.create(
    conversation=conversation.id,
    extra_body={
        "agent": {
            "name": "web-search-agent",
            "type": "agent_reference"
        }
    },
    input = user_query
)

print(f"Agent response: {response.output_text}")
# Out:
# Agent response: Here are some of the latest advancements in renewable energy, based on key trends and innovations observed in 2026:
#
# ### 1. **Advanced Energy Storage Technologies**
#    - **Next-Generation Batteries**: Developments in lithium-silicon, sodium-ion batteries, and long-duration energy storage solutions are key innovations to improve energy reliability and support high renewable penetration in grids [StartUs Insights](https://www.startus-insights.com/innovators-guide/renewable-energy-trends/).
#    - **Grid-Scale Storage**: Expanded deployment of large-scale storage systems ensures steady, reliable energy despite fluctuations in solar and wind output [Renewable Energy Blog](https://www.renewableenergyconference.org/blog/trends-in-renewable-energy-2026.html).
#
# ### 2. **Green Hydrogen Development**
#    - Green hydrogen is gaining traction to decarbonize hard-to-abate sectors such as steelmaking, cement, and aviation. Costs for electrolyzers are dropping due to economies of scale and innovation [Renewable Energy Blog](https://www.renewableenergyconference.org/blog/trends-in-renewable-energy-2026.html).
#    - Hydrogen hubs are being established globally, particularly in Europe, the Middle East, and Asia [Deloitte Insights](https://www.deloitte.com/us/en/insights/industry/renewable-energy/renewable-energy-industry-outlook.html).
#
# ### 3. **AI and Digital Integration in Energy Systems**
#    - **Smart Grids**: Artificial intelligence (AI) and Internet of Things (IoT) technologies are optimizing energy distribution, providing predictive maintenance, and enhancing grid resilience [StartUs Insights](https://www.startus-insights.com/innovators-guide/renewable-energy-trends/).
#    - **Blockchain-Enabled Energy Trading**: Blockchain supports decentralized energy markets and increases transparency in energy transactions [S&P Global](https://www.spglobal.com/energy/en/news-research/special-reports/energy-transition/horizons-top-cleantech-trends-2026).
#
# ### 4. **Offshore Wind Expansion**
#    - Progress in floating offshore wind farms is unlocking wind energy potential in deeper waters, particularly in regions like the North Sea, U.S. East Coast, and Asia-Pacific [Renewable Energy Blog](https://www.renewableenergyconference.org/blog/trends-in-renewable-energy-2026.html).
#    - Hybrid systems, coupling wind with hydrogen or solar, are also emerging as innovative solutions [StartUs Insights](https://www.startus-insights.com/innovators-guide/renewable-energy-trends/).
#
# ### 5. **Perovskite Solar Cells and Urban Integration**
#    - **Perovskite Solar Cells**: These advanced materials are entering commercial markets, offering higher efficiency and lower costs compared to traditional photovoltaic cells [Renewable Energy Blog](https://www.renewableenergyconference.org/blog/trends-in-renewable-energy-2026.html).
#    - **Building-Integrated Photovoltaics (BIPV)**: Solar panels are being seamlessly integrated into infrastructure, such as rooftops and facades, reducing urban carbon footprints [pv magazine](https://pv-magazine-usa.com/2025/10/30/five-trends-that-will-shape-renewable-energy-in-2026/).
#
# ### 6. **Energy Efficiency Measures**
#    - With advancements in energy management systems and retrofitting older technologies, overall energy consumption is becoming more efficient, particularly in data centers driven by AI growth [S&P Global](https://www.spglobal.com/energy/en/news-research/special-reports/energy-transition/horizons-top-cleantech-trends-2026).
#
# ### 7. **Bioenergy and Waste-to-Energy Initiatives**
#    - Expanded use of biogas, biomass, and waste-to-energy technologies is helping rural and urban areas transition toward circular, sustainable energy systems [Renewable Energy Blog](https://www.renewableenergyconference.org/blog/trends-in-renewable-energy-2026.html).
#
# These advancements reflect how renewable energy is evolving to become more efficient, resilient, and integrated into modern economies.
