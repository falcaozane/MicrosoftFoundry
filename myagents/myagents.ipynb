# %%
# !pip install azure-ai-projects>=2.0.0
# Out:
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: C:\Users\zvijayfa\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
# Before running the sample:
#    pip install azure-ai-projects>=2.0.0

from azure.identity import DefaultAzureCredential
from azure.ai.projects import AIProjectClient

my_endpoint = "https://udemydemoprojectzane.services.ai.azure.com/api/projects/udemy-demoproj-zane"

project_client = AIProjectClient(
    endpoint=my_endpoint,
    credential=DefaultAzureCredential(),
)

my_agent = "demo-agent"
my_version = "2"

openai_client = project_client.get_openai_client()

# Reference the agent to get a response
response = openai_client.responses.create(
    input=[{"role": "user", "content": "Tell me what you can help with."}],
    extra_body={"agent_reference": {"name": my_agent, "version": my_version, "type": "agent_reference"}},
)

print(f"Response output: {response.output_text}")
# Out:
# Response output: I’m here to assist with a wide variety of tasks and questions! Here’s a general idea of what I can help with:
#
# ### **Information and Research**
# - Providing explanations or summaries of complex topics.
# - Answering questions about history, science, math, technology, and more.
# - Finding recent information, news, or updates using web searches.
# - Giving citations for factual claims or statistics.
#
# ### **Work and Productivity**
# - Assisting with writing, editing, or proofreading.
# - Preparing emails, reports, or presentations.
# - Generating ideas, outlines, or strategies.
# - Performing calculations or creating schedules.
#
# ### **Learning and Education**
# - Tutoring for subjects like math, science, or language learning.
# - Providing study tips or creating flashcards.
# - Simplifying difficult concepts for better understanding.
# - Programming help with code debugging or explanations.
#
# ### **Daily Life Support**
# - Recommending recipes, entertainment, or books.
# - Helping with travel planning, itineraries, or local recommendations.
# - Offering fitness routines or wellness advice (non-medical).
# - Answering questions about places, events, or businesses.
#
# ### **Tech Support**
# - Explaining how to use software or troubleshoot common problems.
# - Offering advice on devices, apps, or online tools.
# - Coding help in languages like Python, JavaScript, and more.
#
# ### **Creative Tasks**
# - Writing poems, stories, or creating other types of creative content.
# - Designing prompts for brainstorming or idea generation.
#
# ### **Customized Searches**
# - Using live web searches for up-to-date information or recent news.
# - Checking facts, product comparisons, travel options, or events.
#
# If there’s something specific you have in mind, let me know. I’m here to help!
