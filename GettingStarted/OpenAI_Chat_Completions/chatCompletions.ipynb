# %% [markdown]
# ## Calling our OpenAI Model from Microsoft Foundry

# %% [markdown]
# ### Installing Required Libraries

# %%
# %pip install azure-ai-projects==2.0.0b2 openai==1.109.1 python-dotenv azure-identity
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting azure-ai-projects==2.0.0b2
#   Downloading azure_ai_projects-2.0.0b2-py3-none-any.whl.metadata (63 kB)
# Collecting openai==1.109.1
#   Using cached openai-1.109.1-py3-none-any.whl.metadata (29 kB)
# Collecting python-dotenv
#   Downloading python_dotenv-1.2.2-py3-none-any.whl.metadata (27 kB)
# Collecting azure-identity
#   Downloading azure_identity-1.25.3-py3-none-any.whl.metadata (91 kB)
# Collecting isodate>=0.6.1 (from azure-ai-projects==2.0.0b2)
#   Downloading isodate-0.7.2-py3-none-any.whl.metadata (11 kB)
# Collecting azure-core>=1.35.0 (from azure-ai-projects==2.0.0b2)
#   Downloading azure_core-1.39.0-py3-none-any.whl.metadata (48 kB)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\zvijayfa\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from azure-ai-projects==2.0.0b2) (4.15.0)
# Collecting azure-storage-blob>=12.15.0 (from azure-ai-projects==2.0.0b2)
#   Downloading azure_storage_blob-12.28.0-py3-none-any.whl.metadata (26 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\zvijayfa\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from openai==1.109.1) (4.10.0)
# Collecting distro<2,>=1.7.0 (from openai==1.109.1)
#   Using cached distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\zvijayfa\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from openai==1.109.1) (0.28.1)
# Collecting jiter<1,>=0.4.0 (from openai==1.109.1)
#   Downloading jiter-0.14.0-cp312-cp312-win_amd64.whl.metadata (5.3 kB)
# Collecting pydantic<3,>=1.9.0 (from openai==1.109.1)
#   Downloading pydantic-2.13.1-py3-none-any.whl.metadata (108 kB)
# Requirement already satisfied: sniffio in c:\users\zvijayfa\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from openai==1.109.1) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\zvijayfa\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from openai==1.109.1) (4.67.1)
# Collecting cryptography>=2.5 (from azure-identity)
#   Downloading cryptography-46.0.7-cp311-abi3-win_amd64.whl.metadata (5.7 kB)
# Collecting msal>=1.35.1 (from azure-identity)
#   Downloading msal-1.36.0-py3-none-any.whl.metadata (11 kB)
# Collecting msal-extensions>=1.2.0 (from azure-identity)
#   Downloading msal_extensions-1.3.1-py3-none-any.whl.metadata (7.8 kB)
# Requirement already satisfied: idna>=2.8 in c:\users\zvijayfa\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from anyio<5,>=3.5.0->openai==1.109.1) (3.10)
# Requirement already satisfied: requests>=2.21.0 in c:\users\zvijayfa\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from azure-core>=1.35.0->azure-ai-projects==2.0.0b2) (2.32.5)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\zvijayfa\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from cryptography>=2.5->azure-identity) (2.0.0)
# Requirement already satisfied: certifi in c:\users\zvijayfa\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from httpx<1,>=0.23.0->openai==1.109.1) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in c:\users\zvijayfa\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from httpx<1,>=0.23.0->openai==1.109.1) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\zvijayfa\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai==1.109.1) (0.16.0)
# Collecting PyJWT<3,>=1.0.0 (from PyJWT[crypto]<3,>=1.0.0->msal>=1.35.1->azure-identity)
#   Downloading pyjwt-2.12.1-py3-none-any.whl.metadata (4.1 kB)
# Collecting annotated-types>=0.6.0 (from pydantic<3,>=1.9.0->openai==1.109.1)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.46.1 (from pydantic<3,>=1.9.0->openai==1.109.1)
#   Downloading pydantic_core-2.46.1-cp312-cp312-win_amd64.whl.metadata (6.7 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic<3,>=1.9.0->openai==1.109.1)
#   Downloading typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: colorama in c:\users\zvijayfa\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from tqdm>4->openai==1.109.1) (0.4.6)
# Requirement already satisfied: pycparser in c:\users\zvijayfa\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from cffi>=2.0.0->cryptography>=2.5->azure-identity) (2.23)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\zvijayfa\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests>=2.21.0->azure-core>=1.35.0->azure-ai-projects==2.0.0b2) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\zvijayfa\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests>=2.21.0->azure-core>=1.35.0->azure-ai-projects==2.0.0b2) (2.5.0)
# Downloading azure_ai_projects-2.0.0b2-py3-none-any.whl (234 kB)
# Using cached openai-1.109.1-py3-none-any.whl (948 kB)
# Downloading python_dotenv-1.2.2-py3-none-any.whl (22 kB)
# Downloading azure_identity-1.25.3-py3-none-any.whl (192 kB)
# Downloading azure_core-1.39.0-py3-none-any.whl (218 kB)
# Downloading azure_storage_blob-12.28.0-py3-none-any.whl (431 kB)
# Downloading cryptography-46.0.7-cp311-abi3-win_amd64.whl (3.5 MB)
#    ---------------------------------------- 0.0/3.5 MB ? eta -:--:--
#    --------------- ------------------------ 1.3/3.5 MB 6.7 MB/s eta 0:00:01
#    ---------------------------------------  3.4/3.5 MB 8.4 MB/s eta 0:00:01
#    ---------------------------------------- 3.5/3.5 MB 7.9 MB/s eta 0:00:00
# Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# Downloading isodate-0.7.2-py3-none-any.whl (22 kB)
# Downloading jiter-0.14.0-cp312-cp312-win_amd64.whl (201 kB)
# Downloading msal-1.36.0-py3-none-any.whl (121 kB)
# Downloading msal_extensions-1.3.1-py3-none-any.whl (20 kB)
# Downloading pydantic-2.13.1-py3-none-any.whl (471 kB)
# Downloading pydantic_core-2.46.1-cp312-cp312-win_amd64.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ----------------------------------- ---- 1.8/2.1 MB 9.1 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 7.7 MB/s eta 0:00:00
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading pyjwt-2.12.1-py3-none-any.whl (29 kB)
# Downloading typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Installing collected packages: typing-inspection, python-dotenv, PyJWT, pydantic-core, jiter, isodate, distro, annotated-types, pydantic, cryptography, azure-core, openai, azure-storage-blob, msal, azure-ai-projects, msal-extensions, azure-identity
# Successfully installed PyJWT-2.12.1 annotated-types-0.7.0 azure-ai-projects-2.0.0b2 azure-core-1.39.0 azure-identity-1.25.3 azure-storage-blob-12.28.0 cryptography-46.0.7 distro-1.9.0 isodate-0.7.2 jiter-0.14.0 msal-1.36.0 msal-extensions-1.3.1 openai-1.109.1 pydantic-2.13.1 pydantic-core-2.46.1 python-dotenv-1.2.2 typing-inspection-0.4.2
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: C:\Users\zvijayfa\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %% [markdown]
# ### Setting up the Environment Variables

# %%
import os
from dotenv import load_dotenv
from azure.identity import DefaultAzureCredential
from azure.ai.projects import AIProjectClient
load_dotenv()

foundry_project_endpoint = os.getenv("FOUNDRY_PROJECT_ENDPOINT")
model_deployment_name = os.getenv("MODEL_DEPLOYMENT_NAME")

# %% [markdown]
# ### Setting up the AI Foundry Project Client

# %%
project_client = AIProjectClient(
    endpoint=foundry_project_endpoint,
    credential=DefaultAzureCredential()
)

# %% [markdown]
# ### Setting up the OpenAI Client

# %%
openai_client = project_client.get_openai_client()

# %% [markdown]
# ### Sending a Request to the OpenAI Model

# %%
response = openai_client.responses.create(
    model=model_deployment_name,
    instructions="You are a helpful AI assistant.",
    input = "Can you tell me about Microsoft Foundry?"
)

print(f"Response output: {response.output_text}")
